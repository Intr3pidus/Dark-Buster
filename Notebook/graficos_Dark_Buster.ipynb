# %%
# %pip install -q --upgrade -r requirements.txt
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
import Atividade_Dark_Patterns.ler_Arquivo as ler
import Atividade_Dark_Patterns.Gemini_Atv as gemini
import Atividade_Dark_Patterns.Openai_Atv as openai

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Alocando os valores nas respectivas variáveis
listaGemini = ler.ler_arquivo_xlsx(r'/workspaces/Dark-Buster/Data/Data_IA_Resultados/gemini_resultaos.xlsx')
listaOpenai = ler.ler_arquivo_xlsx(r'/workspaces/Dark-Buster/Data/Data_IA_Resultados/openai_resultaos.xlsx')

print("Dark patterns da IA do Gemini:")
display(listaGemini)

print("Dark patterns da IA do Openai:")
display(listaOpenai)
# Out:
# Dark patterns da IA do Gemini:
# [{'manipulative_design': True,
#   'url': 'https://www.amazon.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.linkedin.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.shein.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.temu.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.netshoes.com.br/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.microsoft.com/edge',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.udemy.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.aliexpress.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.shopee.com.br/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.fortune-tiger.net/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': False,
#   'url': 'https://www.google.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.wikipedia.org/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.duckduckgo.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.mozilla.org/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.github.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://stackoverflow.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.khanacademy.org/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.gutenberg.org/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.vimeo.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.un.org/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://signal.org/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://proton.me/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.ecosia.org/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://archive.org/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://ethical.net/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': True,
#   'url': 'https://www.theguardian.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://neal.fun/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://wordpress.org/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://www.adobe.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://www.youtube.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://www.evernote.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://medium.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': False,
#   'url': 'https://mail.google.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': False,
#   'url': 'https://maps.google.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': False,
#   'url': 'https://www.ted.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://www.canva.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': False,
#   'url': 'https://www.spotify.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': False,
#   'url': 'https://www.trello.com/',
#   'Fonte': 'Gemini',
#   'manipulative_design_Buscados': nan}]
# Dark patterns da IA do Openai:
# [{'manipulative_design': True,
#   'url': 'https://www.amazon.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.linkedin.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.shein.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.temu.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.netshoes.com.br/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': False,
#   'url': 'https://www.microsoft.com/edge',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.udemy.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.aliexpress.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.shopee.com.br/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': True,
#   'url': 'https://www.fortune-tiger.net/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 1.0},
#  {'manipulative_design': False,
#   'url': 'https://www.google.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.wikipedia.org/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.duckduckgo.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.mozilla.org/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.github.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://stackoverflow.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.khanacademy.org/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.gutenberg.org/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.vimeo.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.un.org/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://signal.org/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://proton.me/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://www.ecosia.org/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://archive.org/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://ethical.net/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': True,
#   'url': 'https://www.theguardian.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://neal.fun/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': 0.0},
#  {'manipulative_design': False,
#   'url': 'https://wordpress.org/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://www.adobe.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://www.youtube.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://www.evernote.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://medium.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': False,
#   'url': 'https://mail.google.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': False,
#   'url': 'https://maps.google.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': False,
#   'url': 'https://www.ted.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://www.canva.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': True,
#   'url': 'https://www.spotify.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan},
#  {'manipulative_design': False,
#   'url': 'https://www.trello.com/',
#   'Fonte': 'Openai',
#   'manipulative_design_Buscados': nan}]

# %%
# 2. Transformando em DataFrames para o gráfico
df_Gemini = pd.DataFrame(listaGemini)[['manipulative_design', 'url']].assign(Fonte = 'Gemini')
df_Openai = pd.DataFrame(listaOpenai)[['manipulative_design', 'url']].assign(Fonte = 'Openai')

# %%
df_Gemini
# Out:
#     manipulative_design                             url   Fonte
# 0                  True         https://www.amazon.com/  Gemini
# 1                  True       https://www.linkedin.com/  Gemini
# 2                  True          https://www.shein.com/  Gemini
# 3                  True           https://www.temu.com/  Gemini
# 4                  True    https://www.netshoes.com.br/  Gemini
# 5                  True  https://www.microsoft.com/edge  Gemini
# 6                  True          https://www.udemy.com/  Gemini
# 7                  True     https://www.aliexpress.com/  Gemini
# 8                  True      https://www.shopee.com.br/  Gemini
# 9                  True  https://www.fortune-tiger.net/  Gemini
# 10                False         https://www.google.com/  Gemini
# 11                False      https://www.wikipedia.org/  Gemini
# 12                False     https://www.duckduckgo.com/  Gemini
# 13                False        https://www.mozilla.org/  Gemini
# 14                False         https://www.github.com/  Gemini
# 15                False      https://stackoverflow.com/  Gemini
# 16                False    https://www.khanacademy.org/  Gemini
# 17                False      https://www.gutenberg.org/  Gemini
# 18                False          https://www.vimeo.com/  Gemini
# 19                False             https://www.un.org/  Gemini
# 20                False             https://signal.org/  Gemini
# 21                False              https://proton.me/  Gemini
# 22                False         https://www.ecosia.org/  Gemini
# 23                False            https://archive.org/  Gemini
# 24                False            https://ethical.net/  Gemini
# 25                 True    https://www.theguardian.com/  Gemini
# 26                False               https://neal.fun/  Gemini
# 27                False          https://wordpress.org/  Gemini
# 28                 True          https://www.adobe.com/  Gemini
# 29                 True        https://www.youtube.com/  Gemini
# 30                 True       https://www.evernote.com/  Gemini
# 31                 True             https://medium.com/  Gemini
# 32                False        https://mail.google.com/  Gemini
# 33                False        https://maps.google.com/  Gemini
# 34                False            https://www.ted.com/  Gemini
# 35                 True          https://www.canva.com/  Gemini
# 36                False        https://www.spotify.com/  Gemini
# 37                False         https://www.trello.com/  Gemini

# %%
df_Openai
# Out:
#     manipulative_design                             url   Fonte
# 0                  True         https://www.amazon.com/  Openai
# 1                  True       https://www.linkedin.com/  Openai
# 2                  True          https://www.shein.com/  Openai
# 3                  True           https://www.temu.com/  Openai
# 4                  True    https://www.netshoes.com.br/  Openai
# 5                 False  https://www.microsoft.com/edge  Openai
# 6                  True          https://www.udemy.com/  Openai
# 7                  True     https://www.aliexpress.com/  Openai
# 8                  True      https://www.shopee.com.br/  Openai
# 9                  True  https://www.fortune-tiger.net/  Openai
# 10                False         https://www.google.com/  Openai
# 11                False      https://www.wikipedia.org/  Openai
# 12                False     https://www.duckduckgo.com/  Openai
# 13                False        https://www.mozilla.org/  Openai
# 14                False         https://www.github.com/  Openai
# 15                False      https://stackoverflow.com/  Openai
# 16                False    https://www.khanacademy.org/  Openai
# 17                False      https://www.gutenberg.org/  Openai
# 18                False          https://www.vimeo.com/  Openai
# 19                False             https://www.un.org/  Openai
# 20                False             https://signal.org/  Openai
# 21                False              https://proton.me/  Openai
# 22                False         https://www.ecosia.org/  Openai
# 23                False            https://archive.org/  Openai
# 24                False            https://ethical.net/  Openai
# 25                 True    https://www.theguardian.com/  Openai
# 26                False               https://neal.fun/  Openai
# 27                False          https://wordpress.org/  Openai
# 28                 True          https://www.adobe.com/  Openai
# 29                 True        https://www.youtube.com/  Openai
# 30                 True       https://www.evernote.com/  Openai
# 31                 True             https://medium.com/  Openai
# 32                False        https://mail.google.com/  Openai
# 33                False        https://maps.google.com/  Openai
# 34                False            https://www.ted.com/  Openai
# 35                 True          https://www.canva.com/  Openai
# 36                 True        https://www.spotify.com/  Openai
# 37                False         https://www.trello.com/  Openai

# %%
print(f"Gemini: \n{df_Gemini['manipulative_design'].value_counts()} \n")
print(f"Openai: \n{df_Openai['manipulative_design'].value_counts()}")
# Out:
# Gemini:
# manipulative_design
# False    22
# True     16
# Name: count, dtype: int64
#
# Openai:
# manipulative_design
# False    22
# True     16
# Name: count, dtype: int64

# %%
# 3. Criando o gráfico comparativo
df_final = pd.concat([df_Gemini, df_Openai])

plt.figure(figsize=(8, 5))
sns.countplot(data = df_final, x = 'manipulative_design', hue = 'Fonte', palette = 'viridis')

plt.title("Comparação de Design Manipulativo entre os IAs Generativas")
plt.xticks([0, 1], ['Íntegro (False)', 'Manipulativo (True)'])
plt.show()

# %%
df_Resultados = pd.read_excel(r"/workspaces/Dark-Buster/Data/Resultados_esperados.xlsx")
df_Resultados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   url                           27 non-null     str
#  1   manipulative_design_Buscados  27 non-null     bool
# dtypes: bool(1), str(1)
# memory usage: 375.0 bytes

# %%
df_Gemini = df_Gemini.merge(df_Resultados, on='url', how='left')
df_Openai = df_Openai.merge(df_Resultados, on='url', how='left')

# %%
mask_validos_Gemini = df_Gemini['manipulative_design'].notna() & df_Gemini['manipulative_design_Buscados'].notna()

acertos_Gemini = (df_Gemini.loc[mask_validos_Gemini, 'manipulative_design'] == df_Gemini.loc[mask_validos_Gemini, 
                                                                                             'manipulative_design_Buscados']).sum()
total_Gemini = mask_validos_Gemini.sum()

proporcao_Gemini = acertos_Gemini / total_Gemini
percentual_Gemini = proporcao_Gemini * 100

if pd.isna(percentual_Gemini):
    percentual_Gemini = 0

print(f"Quantidade de acertos do Gemini {acertos_Gemini}")
print(f"Percentual de acertos do Gemini {percentual_Gemini}")
# Out:
# Quantidade de acertos do Gemini 26
# Percentual de acertos do Gemini 96.29629629629629

# %%
erros_Gemini = total_Gemini - acertos_Gemini

labels_Gemini = ['Acertos', 'Erros']
valores_Gemini = [acertos_Gemini, erros_Gemini]

# %%
plt.bar(labels_Gemini, valores_Gemini)
plt.title(f'Proporção de análises corretas para o Gemini ({percentual_Gemini:.2f}%)')
plt.ylabel('Quantidade')
plt.show()

# %%
mask_validos_Openai = df_Openai['manipulative_design'].notna() & df_Openai['manipulative_design_Buscados'].notna()

acertos_Openai = (df_Openai.loc[mask_validos_Openai, 'manipulative_design'] == df_Openai.loc[mask_validos_Openai, 
                                                                                             'manipulative_design_Buscados']).sum()
total_Openai = mask_validos_Openai.sum()

proporcao_Openai = acertos_Openai / total_Openai
percentual_Openai = proporcao_Openai * 100

if pd.isna(percentual_Openai):
    percentual_Openai = 0

print(f"Quantidade de acertos do Openai {acertos_Openai}")
print(f"Percentual de acertos do Openai {percentual_Openai}")
# Out:
# Quantidade de acertos do Openai 25
# Percentual de acertos do Openai 92.5925925925926

# %%
erros_Openai = total_Openai - acertos_Openai

labels_Openai = ['Acertos', 'Erros']
valores_Openai = [acertos_Openai, erros_Gemini]

# %%
plt.bar(labels_Openai, valores_Openai)
plt.title(f'Proporção de análises corretas para o Openai ({percentual_Openai:.2f}%)')
plt.ylabel('Quantidade')
plt.show()
